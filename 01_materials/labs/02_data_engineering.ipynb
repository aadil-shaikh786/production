# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss dask vs pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance and we will use the API provided by the library yfinance.
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# ![Medallion Architecture (DataBicks)](./images/02_medallion_architecture.png)
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class that will help us control the process of obtaining and transforming our data.
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# # Download Data from Yahoo Finance
#
# Yahoo Finance provides information about public stocks in different markets. The library yfinance gives us access to a fair bit of the data in Yahoo Finance.
#
# These steps are based on the instructions in:
#
# + [yfinance documentation](https://pypi.org/project/yfinance/)
# + [Tutorial in geeksforgeeks.org](https://www.geeksforgeeks.org/get-financial-data-from-yahoo-finance-with-python/)

# %% [markdown]
# + If required, install: `python -m pip install yfinance`.
# + To download the price history of a stock, first use the following setup:

# %%
import pandas as pd
import yfinance as yf
import os
import sys

sys.path.append(os.getenv('SRC_DIR'))

# %% [markdown]
# A few things to notice in the code chunk above:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager (pip in this case, but could be conda, poetry, etc.)
# + The command `sys.path.append("../05_src/)` will add the `../05_src/` directory to the path in the Notebook's kernel. This way, we can use our modules as part of the notebook.
# + Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by the documentation.

# %% [markdown]
# Now, to download the historical price data for a stock, we could use:

# %%
stock = yf.Ticker("AAPL")
px = stock.history(start = "2013-12-01", end = "2024-02-01")
# Out:
# Failed to get ticker 'AAPL' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)
# $AAPL: possibly delisted; No timezone found

# %% [markdown]
# ## Parametrize the download
#
# + Generally, we will look to separate every parameter and setting from functions.
# + If we had a few stocks, we could cycle through them. We need a place to store the list of tickers (a db or file, for example).
# + Store a csv file with a few stock tickers. The location of the file is a setting, the contents of this file are parameters.
# + Use **environment variables** to pass parameters.

# %%
ticker_file = os.getenv("TICKERS")
tickers = pd.read_csv(ticker_file).sample(50, random_state=42)

# %% [markdown]
# Collecting padas data frames
#
# + From the [documentation](https://pandas.pydata.org/docs/user_guide/merging.html):
#
# > [`concat()`](https://pandas.pydata.org/docs/reference/api/pandas.concat.html#pandas.concat) makes a full copy of the data, and iteratively reusing `concat()` can create unnecessary copies. Collect all DataFrame or Series objects in a list before using `concat()`.
#
# + We can string operation togethers using dot operations. Enclose the line in parenthesis and add linebreaks for readability.

# %%
# List to hold final results
px_list = list()

for k, row in tickers.iterrows():  # Produces an iterator that returns index and row

    stock = yf.Ticker(row['ticker'])
    print(f'Processing {row["ticker"]}')
    
    px = (stock
          .history(start = pd.to_datetime("2013-12-01"), 
                   end = pd.to_datetime("2024-02-01"))
          .reset_index()   # Reset index to get date as a column
          .assign(ticker = row['ticker']))    # Add ticker
    
    if px.shape[0] == 0:
        print(f'No data for {row["ticker"]}')  # Validate: do not fail silently.
        continue
    print(f'Downloaded {px.shape}.')
    px_list.append(px)
px_dt = pd.concat(px_list, axis = 0)
print(f'Final shape {px_dt.shape}.')
# Out:
# Processing JCI
# Downloaded (2558, 9).
# Processing BSX
# Downloaded (2558, 9).
# Processing LIN
# Failed to get ticker 'LIN' reason: Expecting value: line 1 column 1 (char 0)
# $LIN: possibly delisted; No timezone found
# No data for LIN
# Processing DOW
# $DOW: possibly delisted; No price data found  (1d 2013-12-01 00:00:00 -> 2024-02-01 00:00:00)
# No data for DOW
# Processing CVX
# Downloaded (2558, 9).
# Processing KHC
# Downloaded (2159, 9).
# Processing RL
# $RL: possibly delisted; No price data found  (1d 2013-12-01 00:00:00 -> 2024-02-01 00:00:00)
# No data for RL
# Processing ED
# Downloaded (2558, 9).
# Processing BX
# Failed to get ticker 'BX' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)
# $BX: possibly delisted; No timezone found
# No data for BX
# Processing IBM
# Downloaded (2558, 9).
# Processing A
# Downloaded (2558, 9).
# Processing FIS
# Downloaded (2558, 9).
# Processing MAS
# Downloaded (2558, 9).
# Processing CPB
# Downloaded (2558, 9).
# Processing PNW
# Downloaded (2558, 9).
# Processing QCOM
# Downloaded (2558, 9).
# Processing YUM
# Failed to get ticker 'YUM' reason: Expecting value: line 1 column 1 (char 0)
# $YUM: possibly delisted; No timezone found
# No data for YUM
# Processing AWK
# Failed to get ticker 'AWK' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)
# $AWK: possibly delisted; No timezone found
# No data for AWK
# Processing MU
# $MU: possibly delisted; No price data found  (1d 2013-12-01 00:00:00 -> 2024-02-01 00:00:00)
# $MU: possibly delisted; No price data found  (1d 2013-12-01 00:00:00 -> 2024-02-01 00:00:00)
# No data for MU
# Processing RCL
# Downloaded (2558, 9).
# Processing WTW
# Downloaded (2558, 9).
# Processing GWW
# Downloaded (2558, 9).
# Processing HAS
# Downloaded (2558, 9).
# Processing PEAK
# $PEAK: possibly delisted; No timezone found
# No data for PEAK
# Processing BR
# Failed to get ticker 'BR' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)
# $BR: possibly delisted; No timezone found
# No data for BR
# Processing VLO
# Downloaded (2558, 9).
# Processing VICI
# Failed to get ticker 'VICI' reason: Expecting value: line 1 column 1 (char 0)
# $VICI: possibly delisted; No timezone found
# No data for VICI
# Processing RHI
# Downloaded (2558, 9).
# Processing CRL
# Failed to get ticker 'CRL' reason: Expecting value: line 1 column 1 (char 0)
# $CRL: possibly delisted; No timezone found
# No data for CRL
# Processing NEM
# Downloaded (2558, 9).
# Processing LYB
# Failed to get ticker 'LYB' reason: Expecting value: line 1 column 1 (char 0)
# $LYB: possibly delisted; No timezone found
# No data for LYB
# Processing GS
# Downloaded (2558, 9).
# Processing V
# Downloaded (2558, 9).
# Processing EPAM
# Downloaded (2558, 9).
# Processing ABT
# Downloaded (2558, 9).
# Processing NFLX
# Downloaded (2558, 9).
# Processing KVUE
# Downloaded (187, 9).
# Processing BKNG
# Downloaded (2558, 9).
# Processing IT
# Downloaded (2558, 9).
# Processing BBY
# Downloaded (2558, 9).
# Processing NUE
# Failed to get ticker 'NUE' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)
# $NUE: possibly delisted; No timezone found
# No data for NUE
# Processing CBRE
# Failed to get ticker 'CBRE' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)
# $CBRE: possibly delisted; No timezone found
# No data for CBRE
# Processing WDC
# Downloaded (2558, 9).
# Processing EXPE
# Downloaded (2558, 9).
# Processing AMGN
# Downloaded (2558, 9).
# Processing BRO
# Downloaded (2558, 9).
# Processing MMM
# Failed to get ticker 'MMM' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)
# $MMM: possibly delisted; No timezone found
# No data for MMM
# Processing ABNB
# $ABNB: possibly delisted; No price data found  (1d 2013-12-01 00:00:00 -> 2024-02-01 00:00:00)
# No data for ABNB
# Processing MDT
# Failed to get ticker 'MDT' reason: Expecting value: line 1 column 1 (char 0)
# $MDT: possibly delisted; No timezone found
# No data for MDT
# Processing AMZN
# Downloaded (2558, 9).
# Final shape (81644, 9).

# %% [markdown]
# ## Reliability
#
# + Keppelman (2017) defines *reliability* as:
#
#     - A system should continue to work correctly.
#     - To work correctly means performing the correct function at the desired level of performance, even in the face of adversity such as hardware or software faults, and even human error.
#
# + *Faults* are things that can go wrong.
# + Sytems that can cope with (certain types of) faults are called *fault-tolerant* or *resilient*.
# + A fault is different than a failure.
#
#     - A *fault* occurs when a component of the system deviates from spec.
#     - A *failure*  is when the system stops providing the required service to the user.
#
# + In our simple example, we handle the fault that occurs when one ticker is not found and log it using *warning*.

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %%
import time

# %%
temp = os.getenv("TEMP_DATA")
os.makedirs(temp, exist_ok=True)
stock_path = os.path.join(temp, "stock_px.csv")

# %%
start = time.time()
px_dt.to_csv(stock_path, index = False)
end = time.time()

print(f'Writing to dt ({px_dt.shape})csv took {end - start} seconds.')
print(f'Csv file size { os.path.getsize(stock_path)*1e-6 } MB')
# Out:
# Writing to dt ((81644, 9))csv took 1.3365046977996826 seconds.
# Csv file size 9.757914 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %%
import dask.dataframe as dd
# Out:
# c:\Users\ADYL\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\_pyarrow_compat.py:17: FutureWarning: Minimal version of pyarrow will soon be increased to 14.0.1. You are using 11.0.0. Please consider upgrading.
#   warnings.warn(
# C:\Users\ADYL\AppData\Local\Temp\ipykernel_22644\676544213.py:1: DeprecationWarning: The current Dask DataFrame implementation is deprecated.
# In a future release, Dask DataFrame will use new implementation that
# contains several improvements including a logical query planning.
# The user-facing DataFrame API will remain unchanged.
#
# The new implementation is already available and can be enabled by
# installing the dask-expr library:
#
#     $ pip install dask-expr
#
# and turning the query planning option on:
#
#     >>> import dask
#     >>> dask.config.set({'dataframe.query-planning': True})
#     >>> import dask.dataframe as dd
#
# API documentation for the new implementation is available at
# https://docs.dask.org/en/stable/dask-expr-api.html
#
# Any feedback can be reported on the Dask issue tracker
# https://github.com/dask/dask/issues
#
#   import dask.dataframe as dd

# %%
px_dd = dd.from_pandas(px_dt, npartitions = len(tickers))
parquet_path = os.path.join(temp, "stock_px.parquet")

start = time.time()
px_dd.to_parquet(parquet_path, engine = "pyarrow")
end = time.time()

print(f'Writing dd ({px_dt.shape}) to parquet took {end - start} seconds.')
print(f'Parquet file size { get_dir_size(parquet_path)*1e-6 } MB')
# Out:
# Writing dd ((81644, 9)) to parquet took 1.278120517730713 seconds.
# Parquet file size 3.890459 MB

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to larrge joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
for ticker in px_dt.ticker.unique():
    ticker_dt = px_dt[px_dt.ticker == ticker]
    ticker_dt = ticker_dt.assign(year = ticker_dt.Date.dt.year)
    for yr in ticker_dt.year.unique():
        yr_dt = ticker_dt[ticker_dt.year == yr]
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}.parquet")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        yr_dt.to_parquet(yr_path, engine = "pyarrow")

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "*/*.parquet"))
dd_px = dd.read_parquet(parquet_files).set_index("ticker")

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %%
import numpy as np
dd_rets = (dd_px.groupby('ticker', group_keys=False).apply(
    lambda x: x.assign(Close_lag_1 = x['Close'].shift(1))
).assign(
    returns = lambda x: x['Close']/x['Close_lag_1'] - 1
).assign(
    positive_return = lambda x: (x['returns'] > 0)*1
))
# Out:
# C:\Users\ADYL\AppData\Local\Temp\ipykernel_22644\3091835559.py:2: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   dd_rets = (dd_px.groupby('ticker', group_keys=False).apply(

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                                             Date     Open     High      Low    Close Volume Dividends Stock Splits   year Close_lag_1  returns positive_return
# npartitions=33
# A               datetime64[ns, America/New_York]  float64  float64  float64  float64  int64   float64      float64  int32     float64  float64           int32
# ABT                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# ...                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# WTW                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# WTW                                          ...      ...      ...      ...      ...    ...       ...          ...    ...         ...      ...             ...
# Dask Name: assign, 18 graph layers

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %%
dd_rets.compute()
# Out:
#                             Date        Open        High         Low  \
# ticker
# A      2013-12-02 00:00:00-05:00   34.875483   35.005930   34.640675
# A      2013-12-03 00:00:00-05:00   34.516752   34.679815   34.281943
# A      2013-12-04 00:00:00-05:00   34.464556   35.110279   34.386289
# A      2013-12-05 00:00:00-05:00   34.797206   35.090715   34.647190
# A      2013-12-06 00:00:00-05:00   35.064632   35.827754   35.064632
# ...                          ...         ...         ...         ...
# WTW    2024-01-25 00:00:00-05:00  249.146372  249.146372  246.065966
# WTW    2024-01-26 00:00:00-05:00  248.799707  248.799707  246.392823
# WTW    2024-01-29 00:00:00-05:00  245.580621  246.739485  243.540226
# WTW    2024-01-30 00:00:00-05:00  243.025165  245.798523  243.025165
# WTW    2024-01-31 00:00:00-05:00  246.046160  247.066357  243.044994
#
#              Close   Volume  Dividends  Stock Splits  year  Close_lag_1  \
# ticker
# A        34.705898  2039962        0.0           0.0  2013          NaN
# A        34.523273  3462706        0.0           0.0  2013    34.705898
# A        34.947216  3377288        0.0           0.0  2013    34.523273
# A        34.895042  2530939        0.0           0.0  2013    34.947216
# A        35.762531  4268513        0.0           0.0  2013    34.895042
# ...            ...      ...        ...           ...   ...          ...
# WTW     248.334183   316700        0.0           0.0  2024   248.601608
# WTW     247.105972   372800        0.0           0.0  2024   248.334183
# WTW     244.094894   340800        0.0           0.0  2024   247.105972
# WTW     245.422134   367900        0.0           0.0  2024   244.094894
# WTW     243.956238   391000        0.0           0.0  2024   245.422134
#
#          returns  positive_return
# ticker
# A            NaN                0
# A      -0.005262                0
# A       0.012280                1
# A      -0.001493                0
# A       0.024860                1
# ...          ...              ...
# WTW    -0.001076                0
# WTW    -0.004946                0
# WTW    -0.012185                0
# WTW     0.005437                1
# WTW    -0.005973                0
#
# [81644 rows x 12 columns]

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %%
# CLean up before start
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)

# %%
FEATURES_DATA = os.getenv("FEATURES_DATA")
dd_rets.to_parquet(FEATURES_DATA, engine = "pyarrow")

# %% [markdown]
# # A few notes
#
# # Jupyter?
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object oriented programming?
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefits from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# Below, we demonstrate how our class implementation works.
#
# Before we begin, clean the price directory (we will download everything again).

# %%
# CLean up before start

if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)

# %% [markdown]
# Now, instantiate a DataManager object and download all the data.

# %%
from data_manager import DataManager
dm = DataManager()

# %%
dm.download_all()
# Out:
# 2024-11-20 13:12:07,582, data_manager.py, 43, INFO, Getting price data for all tickers.
# 2024-11-20 13:12:07,582, data_manager.py, 43, INFO, Getting price data for all tickers.
# 2024-11-20 13:12:07,585, data_manager.py, 52, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2024-11-20 13:12:07,585, data_manager.py, 52, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2024-11-20 13:12:07,593, data_manager.py, 58, INFO, Processing all tickers
# 2024-11-20 13:12:07,593, data_manager.py, 58, INFO, Processing all tickers
# 2024-11-20 13:12:07,601, data_manager.py, 73, INFO, Processing ticker MMM
# 2024-11-20 13:12:07,601, data_manager.py, 73, INFO, Processing ticker MMM
# 2024-11-20 13:12:07,603, data_manager.py, 109, INFO, Getting stock price data for MMM from 2000-01-01 to 2024-11-20
# 2024-11-20 13:12:07,603, data_manager.py, 109, INFO, Getting stock price data for MMM from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:12:13,403, data_manager.py, 83, INFO, Saving data for MMM by year
# 2024-11-20 13:12:13,403, data_manager.py, 83, INFO, Saving data for MMM by year
# 2024-11-20 13:12:14,581, data_manager.py, 73, INFO, Processing ticker AOS
# 2024-11-20 13:12:14,581, data_manager.py, 73, INFO, Processing ticker AOS
# 2024-11-20 13:12:14,583, data_manager.py, 109, INFO, Getting stock price data for AOS from 2000-01-01 to 2024-11-20
# 2024-11-20 13:12:14,583, data_manager.py, 109, INFO, Getting stock price data for AOS from 2000-01-01 to 2024-11-20
# Failed to get ticker 'AOS' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AOS']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# 2024-11-20 13:12:15,375, data_manager.py, 83, INFO, Saving data for AOS by year
# 2024-11-20 13:12:15,375, data_manager.py, 83, INFO, Saving data for AOS by year
# 2024-11-20 13:12:15,378, data_manager.py, 101, WARNING, No data found for AOS
# 2024-11-20 13:12:15,378, data_manager.py, 101, WARNING, No data found for AOS
# 2024-11-20 13:12:15,384, data_manager.py, 73, INFO, Processing ticker ABT
# 2024-11-20 13:12:15,384, data_manager.py, 73, INFO, Processing ticker ABT
# 2024-11-20 13:12:15,388, data_manager.py, 109, INFO, Getting stock price data for ABT from 2000-01-01 to 2024-11-20
# 2024-11-20 13:12:15,388, data_manager.py, 109, INFO, Getting stock price data for ABT from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:12:17,750, data_manager.py, 83, INFO, Saving data for ABT by year
# 2024-11-20 13:12:17,750, data_manager.py, 83, INFO, Saving data for ABT by year
# 2024-11-20 13:12:18,695, data_manager.py, 73, INFO, Processing ticker ABBV
# 2024-11-20 13:12:18,695, data_manager.py, 73, INFO, Processing ticker ABBV
# 2024-11-20 13:12:18,697, data_manager.py, 109, INFO, Getting stock price data for ABBV from 2000-01-01 to 2024-11-20
# 2024-11-20 13:12:18,697, data_manager.py, 109, INFO, Getting stock price data for ABBV from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:12:22,181, data_manager.py, 83, INFO, Saving data for ABBV by year
# 2024-11-20 13:12:22,181, data_manager.py, 83, INFO, Saving data for ABBV by year
# 2024-11-20 13:12:22,640, data_manager.py, 73, INFO, Processing ticker ACN
# 2024-11-20 13:12:22,640, data_manager.py, 73, INFO, Processing ticker ACN
# 2024-11-20 13:12:22,642, data_manager.py, 109, INFO, Getting stock price data for ACN from 2000-01-01 to 2024-11-20
# 2024-11-20 13:12:22,642, data_manager.py, 109, INFO, Getting stock price data for ACN from 2000-01-01 to 2024-11-20
# Failed to get ticker 'ACN' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ACN']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# 2024-11-20 13:12:32,686, data_manager.py, 83, INFO, Saving data for ACN by year
# 2024-11-20 13:12:32,686, data_manager.py, 83, INFO, Saving data for ACN by year
# 2024-11-20 13:12:32,689, data_manager.py, 101, WARNING, No data found for ACN
# 2024-11-20 13:12:32,689, data_manager.py, 101, WARNING, No data found for ACN
# 2024-11-20 13:12:32,691, data_manager.py, 73, INFO, Processing ticker ADBE
# 2024-11-20 13:12:32,691, data_manager.py, 73, INFO, Processing ticker ADBE
# 2024-11-20 13:12:32,693, data_manager.py, 109, INFO, Getting stock price data for ADBE from 2000-01-01 to 2024-11-20
# 2024-11-20 13:12:32,693, data_manager.py, 109, INFO, Getting stock price data for ADBE from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:12:36,556, data_manager.py, 83, INFO, Saving data for ADBE by year
# 2024-11-20 13:12:36,556, data_manager.py, 83, INFO, Saving data for ADBE by year
# 2024-11-20 13:12:37,517, data_manager.py, 73, INFO, Processing ticker AMD
# 2024-11-20 13:12:37,517, data_manager.py, 73, INFO, Processing ticker AMD
# 2024-11-20 13:12:37,518, data_manager.py, 109, INFO, Getting stock price data for AMD from 2000-01-01 to 2024-11-20
# 2024-11-20 13:12:37,518, data_manager.py, 109, INFO, Getting stock price data for AMD from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:12:38,822, data_manager.py, 83, INFO, Saving data for AMD by year
# 2024-11-20 13:12:38,822, data_manager.py, 83, INFO, Saving data for AMD by year
# 2024-11-20 13:12:39,873, data_manager.py, 73, INFO, Processing ticker AES
# 2024-11-20 13:12:39,873, data_manager.py, 73, INFO, Processing ticker AES
# 2024-11-20 13:12:39,874, data_manager.py, 109, INFO, Getting stock price data for AES from 2000-01-01 to 2024-11-20
# 2024-11-20 13:12:39,874, data_manager.py, 109, INFO, Getting stock price data for AES from 2000-01-01 to 2024-11-20
# Failed to get ticker 'AES' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AES']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# 2024-11-20 13:12:49,929, data_manager.py, 83, INFO, Saving data for AES by year
# 2024-11-20 13:12:49,929, data_manager.py, 83, INFO, Saving data for AES by year
# 2024-11-20 13:12:49,937, data_manager.py, 101, WARNING, No data found for AES
# 2024-11-20 13:12:49,937, data_manager.py, 101, WARNING, No data found for AES
# 2024-11-20 13:12:49,945, data_manager.py, 73, INFO, Processing ticker AFL
# 2024-11-20 13:12:49,945, data_manager.py, 73, INFO, Processing ticker AFL
# 2024-11-20 13:12:49,952, data_manager.py, 109, INFO, Getting stock price data for AFL from 2000-01-01 to 2024-11-20
# 2024-11-20 13:12:49,952, data_manager.py, 109, INFO, Getting stock price data for AFL from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AFL']: JSONDecodeError('Expecting value: line 1 column 1 (char 0)')
# 2024-11-20 13:12:51,895, data_manager.py, 83, INFO, Saving data for AFL by year
# 2024-11-20 13:12:51,895, data_manager.py, 83, INFO, Saving data for AFL by year
# 2024-11-20 13:12:51,900, data_manager.py, 101, WARNING, No data found for AFL
# 2024-11-20 13:12:51,900, data_manager.py, 101, WARNING, No data found for AFL
# 2024-11-20 13:12:51,906, data_manager.py, 73, INFO, Processing ticker A
# 2024-11-20 13:12:51,906, data_manager.py, 73, INFO, Processing ticker A
# 2024-11-20 13:12:51,910, data_manager.py, 109, INFO, Getting stock price data for A from 2000-01-01 to 2024-11-20
# 2024-11-20 13:12:51,910, data_manager.py, 109, INFO, Getting stock price data for A from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:12:56,636, data_manager.py, 83, INFO, Saving data for A by year
# 2024-11-20 13:12:56,636, data_manager.py, 83, INFO, Saving data for A by year
# 2024-11-20 13:12:57,699, data_manager.py, 73, INFO, Processing ticker APD
# 2024-11-20 13:12:57,699, data_manager.py, 73, INFO, Processing ticker APD
# 2024-11-20 13:12:57,701, data_manager.py, 109, INFO, Getting stock price data for APD from 2000-01-01 to 2024-11-20
# 2024-11-20 13:12:57,701, data_manager.py, 109, INFO, Getting stock price data for APD from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:13:01,254, data_manager.py, 83, INFO, Saving data for APD by year
# 2024-11-20 13:13:01,254, data_manager.py, 83, INFO, Saving data for APD by year
# 2024-11-20 13:13:02,203, data_manager.py, 73, INFO, Processing ticker ABNB
# 2024-11-20 13:13:02,203, data_manager.py, 73, INFO, Processing ticker ABNB
# 2024-11-20 13:13:02,206, data_manager.py, 109, INFO, Getting stock price data for ABNB from 2000-01-01 to 2024-11-20
# 2024-11-20 13:13:02,206, data_manager.py, 109, INFO, Getting stock price data for ABNB from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:13:03,061, data_manager.py, 83, INFO, Saving data for ABNB by year
# 2024-11-20 13:13:03,061, data_manager.py, 83, INFO, Saving data for ABNB by year
# 2024-11-20 13:13:03,258, data_manager.py, 73, INFO, Processing ticker AKAM
# 2024-11-20 13:13:03,258, data_manager.py, 73, INFO, Processing ticker AKAM
# 2024-11-20 13:13:03,259, data_manager.py, 109, INFO, Getting stock price data for AKAM from 2000-01-01 to 2024-11-20
# 2024-11-20 13:13:03,259, data_manager.py, 109, INFO, Getting stock price data for AKAM from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:13:06,274, data_manager.py, 83, INFO, Saving data for AKAM by year
# 2024-11-20 13:13:06,274, data_manager.py, 83, INFO, Saving data for AKAM by year
# 2024-11-20 13:13:07,239, data_manager.py, 73, INFO, Processing ticker ALB
# 2024-11-20 13:13:07,239, data_manager.py, 73, INFO, Processing ticker ALB
# 2024-11-20 13:13:07,241, data_manager.py, 109, INFO, Getting stock price data for ALB from 2000-01-01 to 2024-11-20
# 2024-11-20 13:13:07,241, data_manager.py, 109, INFO, Getting stock price data for ALB from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:13:15,996, data_manager.py, 83, INFO, Saving data for ALB by year
# 2024-11-20 13:13:15,996, data_manager.py, 83, INFO, Saving data for ALB by year
# 2024-11-20 13:13:16,933, data_manager.py, 73, INFO, Processing ticker ARE
# 2024-11-20 13:13:16,933, data_manager.py, 73, INFO, Processing ticker ARE
# 2024-11-20 13:13:16,934, data_manager.py, 109, INFO, Getting stock price data for ARE from 2000-01-01 to 2024-11-20
# 2024-11-20 13:13:16,934, data_manager.py, 109, INFO, Getting stock price data for ARE from 2000-01-01 to 2024-11-20
# Failed to get ticker 'ARE' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ARE']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# 2024-11-20 13:13:17,820, data_manager.py, 83, INFO, Saving data for ARE by year
# 2024-11-20 13:13:17,820, data_manager.py, 83, INFO, Saving data for ARE by year
# 2024-11-20 13:13:17,822, data_manager.py, 101, WARNING, No data found for ARE
# 2024-11-20 13:13:17,822, data_manager.py, 101, WARNING, No data found for ARE
# 2024-11-20 13:13:17,824, data_manager.py, 73, INFO, Processing ticker ALGN
# 2024-11-20 13:13:17,824, data_manager.py, 73, INFO, Processing ticker ALGN
# 2024-11-20 13:13:17,824, data_manager.py, 109, INFO, Getting stock price data for ALGN from 2000-01-01 to 2024-11-20
# 2024-11-20 13:13:17,824, data_manager.py, 109, INFO, Getting stock price data for ALGN from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:13:19,267, data_manager.py, 83, INFO, Saving data for ALGN by year
# 2024-11-20 13:13:19,267, data_manager.py, 83, INFO, Saving data for ALGN by year
# 2024-11-20 13:13:20,195, data_manager.py, 73, INFO, Processing ticker ALLE
# 2024-11-20 13:13:20,195, data_manager.py, 73, INFO, Processing ticker ALLE
# 2024-11-20 13:13:20,197, data_manager.py, 109, INFO, Getting stock price data for ALLE from 2000-01-01 to 2024-11-20
# 2024-11-20 13:13:20,197, data_manager.py, 109, INFO, Getting stock price data for ALLE from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:13:23,726, data_manager.py, 83, INFO, Saving data for ALLE by year
# 2024-11-20 13:13:23,726, data_manager.py, 83, INFO, Saving data for ALLE by year
# 2024-11-20 13:13:24,208, data_manager.py, 73, INFO, Processing ticker LNT
# 2024-11-20 13:13:24,208, data_manager.py, 73, INFO, Processing ticker LNT
# 2024-11-20 13:13:24,210, data_manager.py, 109, INFO, Getting stock price data for LNT from 2000-01-01 to 2024-11-20
# 2024-11-20 13:13:24,210, data_manager.py, 109, INFO, Getting stock price data for LNT from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:13:27,228, data_manager.py, 83, INFO, Saving data for LNT by year
# 2024-11-20 13:13:27,228, data_manager.py, 83, INFO, Saving data for LNT by year
# 2024-11-20 13:13:28,261, data_manager.py, 73, INFO, Processing ticker ALL
# 2024-11-20 13:13:28,261, data_manager.py, 73, INFO, Processing ticker ALL
# 2024-11-20 13:13:28,264, data_manager.py, 109, INFO, Getting stock price data for ALL from 2000-01-01 to 2024-11-20
# 2024-11-20 13:13:28,264, data_manager.py, 109, INFO, Getting stock price data for ALL from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:13:36,613, data_manager.py, 83, INFO, Saving data for ALL by year
# 2024-11-20 13:13:36,613, data_manager.py, 83, INFO, Saving data for ALL by year
# 2024-11-20 13:13:37,577, data_manager.py, 73, INFO, Processing ticker GOOGL
# 2024-11-20 13:13:37,577, data_manager.py, 73, INFO, Processing ticker GOOGL
# 2024-11-20 13:13:37,578, data_manager.py, 109, INFO, Getting stock price data for GOOGL from 2000-01-01 to 2024-11-20
# 2024-11-20 13:13:37,578, data_manager.py, 109, INFO, Getting stock price data for GOOGL from 2000-01-01 to 2024-11-20
# Failed to get ticker 'GOOGL' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['GOOGL']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# 2024-11-20 13:13:38,504, data_manager.py, 83, INFO, Saving data for GOOGL by year
# 2024-11-20 13:13:38,504, data_manager.py, 83, INFO, Saving data for GOOGL by year
# 2024-11-20 13:13:38,509, data_manager.py, 101, WARNING, No data found for GOOGL
# 2024-11-20 13:13:38,509, data_manager.py, 101, WARNING, No data found for GOOGL
# 2024-11-20 13:13:38,512, data_manager.py, 73, INFO, Processing ticker GOOG
# 2024-11-20 13:13:38,512, data_manager.py, 73, INFO, Processing ticker GOOG
# 2024-11-20 13:13:38,516, data_manager.py, 109, INFO, Getting stock price data for GOOG from 2000-01-01 to 2024-11-20
# 2024-11-20 13:13:38,516, data_manager.py, 109, INFO, Getting stock price data for GOOG from 2000-01-01 to 2024-11-20
# Failed to get ticker 'GOOG' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['GOOG']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# 2024-11-20 13:13:39,346, data_manager.py, 83, INFO, Saving data for GOOG by year
# 2024-11-20 13:13:39,346, data_manager.py, 83, INFO, Saving data for GOOG by year
# 2024-11-20 13:13:39,350, data_manager.py, 101, WARNING, No data found for GOOG
# 2024-11-20 13:13:39,350, data_manager.py, 101, WARNING, No data found for GOOG
# 2024-11-20 13:13:39,352, data_manager.py, 73, INFO, Processing ticker MO
# 2024-11-20 13:13:39,352, data_manager.py, 73, INFO, Processing ticker MO
# 2024-11-20 13:13:39,353, data_manager.py, 109, INFO, Getting stock price data for MO from 2000-01-01 to 2024-11-20
# 2024-11-20 13:13:39,353, data_manager.py, 109, INFO, Getting stock price data for MO from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:13:42,419, data_manager.py, 83, INFO, Saving data for MO by year
# 2024-11-20 13:13:42,419, data_manager.py, 83, INFO, Saving data for MO by year
# 2024-11-20 13:13:43,413, data_manager.py, 73, INFO, Processing ticker AMZN
# 2024-11-20 13:13:43,413, data_manager.py, 73, INFO, Processing ticker AMZN
# 2024-11-20 13:13:43,414, data_manager.py, 109, INFO, Getting stock price data for AMZN from 2000-01-01 to 2024-11-20
# 2024-11-20 13:13:43,414, data_manager.py, 109, INFO, Getting stock price data for AMZN from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:13:46,818, data_manager.py, 83, INFO, Saving data for AMZN by year
# 2024-11-20 13:13:46,818, data_manager.py, 83, INFO, Saving data for AMZN by year
# 2024-11-20 13:13:47,793, data_manager.py, 73, INFO, Processing ticker AMCR
# 2024-11-20 13:13:47,793, data_manager.py, 73, INFO, Processing ticker AMCR
# 2024-11-20 13:13:47,795, data_manager.py, 109, INFO, Getting stock price data for AMCR from 2000-01-01 to 2024-11-20
# 2024-11-20 13:13:47,795, data_manager.py, 109, INFO, Getting stock price data for AMCR from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:13:50,238, data_manager.py, 83, INFO, Saving data for AMCR by year
# 2024-11-20 13:13:50,238, data_manager.py, 83, INFO, Saving data for AMCR by year
# 2024-11-20 13:13:50,854, data_manager.py, 73, INFO, Processing ticker AEE
# 2024-11-20 13:13:50,854, data_manager.py, 73, INFO, Processing ticker AEE
# 2024-11-20 13:13:50,856, data_manager.py, 109, INFO, Getting stock price data for AEE from 2000-01-01 to 2024-11-20
# 2024-11-20 13:13:50,856, data_manager.py, 109, INFO, Getting stock price data for AEE from 2000-01-01 to 2024-11-20
# Failed to get ticker 'AEE' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AEE']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# 2024-11-20 13:14:00,906, data_manager.py, 83, INFO, Saving data for AEE by year
# 2024-11-20 13:14:00,906, data_manager.py, 83, INFO, Saving data for AEE by year
# 2024-11-20 13:14:00,909, data_manager.py, 101, WARNING, No data found for AEE
# 2024-11-20 13:14:00,909, data_manager.py, 101, WARNING, No data found for AEE
# 2024-11-20 13:14:00,910, data_manager.py, 73, INFO, Processing ticker AAL
# 2024-11-20 13:14:00,910, data_manager.py, 73, INFO, Processing ticker AAL
# 2024-11-20 13:14:00,913, data_manager.py, 109, INFO, Getting stock price data for AAL from 2000-01-01 to 2024-11-20
# 2024-11-20 13:14:00,913, data_manager.py, 109, INFO, Getting stock price data for AAL from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:14:06,877, data_manager.py, 83, INFO, Saving data for AAL by year
# 2024-11-20 13:14:06,877, data_manager.py, 83, INFO, Saving data for AAL by year
# 2024-11-20 13:14:07,660, data_manager.py, 73, INFO, Processing ticker AEP
# 2024-11-20 13:14:07,660, data_manager.py, 73, INFO, Processing ticker AEP
# 2024-11-20 13:14:07,661, data_manager.py, 109, INFO, Getting stock price data for AEP from 2000-01-01 to 2024-11-20
# 2024-11-20 13:14:07,661, data_manager.py, 109, INFO, Getting stock price data for AEP from 2000-01-01 to 2024-11-20
# Failed to get ticker 'AEP' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AEP']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# 2024-11-20 13:14:08,509, data_manager.py, 83, INFO, Saving data for AEP by year
# 2024-11-20 13:14:08,509, data_manager.py, 83, INFO, Saving data for AEP by year
# 2024-11-20 13:14:08,511, data_manager.py, 101, WARNING, No data found for AEP
# 2024-11-20 13:14:08,511, data_manager.py, 101, WARNING, No data found for AEP
# 2024-11-20 13:14:08,512, data_manager.py, 73, INFO, Processing ticker AXP
# 2024-11-20 13:14:08,512, data_manager.py, 73, INFO, Processing ticker AXP
# 2024-11-20 13:14:08,513, data_manager.py, 109, INFO, Getting stock price data for AXP from 2000-01-01 to 2024-11-20
# 2024-11-20 13:14:08,513, data_manager.py, 109, INFO, Getting stock price data for AXP from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:14:14,300, data_manager.py, 83, INFO, Saving data for AXP by year
# 2024-11-20 13:14:14,300, data_manager.py, 83, INFO, Saving data for AXP by year
# 2024-11-20 13:14:15,276, data_manager.py, 73, INFO, Processing ticker AIG
# 2024-11-20 13:14:15,276, data_manager.py, 73, INFO, Processing ticker AIG
# 2024-11-20 13:14:15,278, data_manager.py, 109, INFO, Getting stock price data for AIG from 2000-01-01 to 2024-11-20
# 2024-11-20 13:14:15,278, data_manager.py, 109, INFO, Getting stock price data for AIG from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:14:16,669, data_manager.py, 83, INFO, Saving data for AIG by year
# 2024-11-20 13:14:16,669, data_manager.py, 83, INFO, Saving data for AIG by year
# 2024-11-20 13:14:17,684, data_manager.py, 73, INFO, Processing ticker AMT
# 2024-11-20 13:14:17,684, data_manager.py, 73, INFO, Processing ticker AMT
# 2024-11-20 13:14:17,685, data_manager.py, 109, INFO, Getting stock price data for AMT from 2000-01-01 to 2024-11-20
# 2024-11-20 13:14:17,685, data_manager.py, 109, INFO, Getting stock price data for AMT from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:14:21,321, data_manager.py, 83, INFO, Saving data for AMT by year
# 2024-11-20 13:14:21,321, data_manager.py, 83, INFO, Saving data for AMT by year
# 2024-11-20 13:14:22,404, data_manager.py, 73, INFO, Processing ticker AWK
# 2024-11-20 13:14:22,404, data_manager.py, 73, INFO, Processing ticker AWK
# 2024-11-20 13:14:22,405, data_manager.py, 109, INFO, Getting stock price data for AWK from 2000-01-01 to 2024-11-20
# 2024-11-20 13:14:22,405, data_manager.py, 109, INFO, Getting stock price data for AWK from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:14:23,929, data_manager.py, 83, INFO, Saving data for AWK by year
# 2024-11-20 13:14:23,929, data_manager.py, 83, INFO, Saving data for AWK by year
# 2024-11-20 13:14:24,582, data_manager.py, 73, INFO, Processing ticker AMP
# 2024-11-20 13:14:24,582, data_manager.py, 73, INFO, Processing ticker AMP
# 2024-11-20 13:14:24,584, data_manager.py, 109, INFO, Getting stock price data for AMP from 2000-01-01 to 2024-11-20
# 2024-11-20 13:14:24,584, data_manager.py, 109, INFO, Getting stock price data for AMP from 2000-01-01 to 2024-11-20
# Failed to get ticker 'AMP' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMP']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# 2024-11-20 13:14:34,622, data_manager.py, 83, INFO, Saving data for AMP by year
# 2024-11-20 13:14:34,622, data_manager.py, 83, INFO, Saving data for AMP by year
# 2024-11-20 13:14:34,623, data_manager.py, 101, WARNING, No data found for AMP
# 2024-11-20 13:14:34,623, data_manager.py, 101, WARNING, No data found for AMP
# 2024-11-20 13:14:34,624, data_manager.py, 73, INFO, Processing ticker AME
# 2024-11-20 13:14:34,624, data_manager.py, 73, INFO, Processing ticker AME
# 2024-11-20 13:14:34,627, data_manager.py, 109, INFO, Getting stock price data for AME from 2000-01-01 to 2024-11-20
# 2024-11-20 13:14:34,627, data_manager.py, 109, INFO, Getting stock price data for AME from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:14:36,084, data_manager.py, 83, INFO, Saving data for AME by year
# 2024-11-20 13:14:36,084, data_manager.py, 83, INFO, Saving data for AME by year
# 2024-11-20 13:14:37,079, data_manager.py, 73, INFO, Processing ticker AMGN
# 2024-11-20 13:14:37,079, data_manager.py, 73, INFO, Processing ticker AMGN
# 2024-11-20 13:14:37,082, data_manager.py, 109, INFO, Getting stock price data for AMGN from 2000-01-01 to 2024-11-20
# 2024-11-20 13:14:37,082, data_manager.py, 109, INFO, Getting stock price data for AMGN from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:14:37,974, data_manager.py, 83, INFO, Saving data for AMGN by year
# 2024-11-20 13:14:37,974, data_manager.py, 83, INFO, Saving data for AMGN by year
# 2024-11-20 13:14:39,034, data_manager.py, 73, INFO, Processing ticker APH
# 2024-11-20 13:14:39,034, data_manager.py, 73, INFO, Processing ticker APH
# 2024-11-20 13:14:39,036, data_manager.py, 109, INFO, Getting stock price data for APH from 2000-01-01 to 2024-11-20
# 2024-11-20 13:14:39,036, data_manager.py, 109, INFO, Getting stock price data for APH from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['APH']: JSONDecodeError('Expecting value: line 1 column 1 (char 0)')
# 2024-11-20 13:14:40,354, data_manager.py, 83, INFO, Saving data for APH by year
# 2024-11-20 13:14:40,354, data_manager.py, 83, INFO, Saving data for APH by year
# 2024-11-20 13:14:40,357, data_manager.py, 101, WARNING, No data found for APH
# 2024-11-20 13:14:40,357, data_manager.py, 101, WARNING, No data found for APH
# 2024-11-20 13:14:40,358, data_manager.py, 73, INFO, Processing ticker ADI
# 2024-11-20 13:14:40,358, data_manager.py, 73, INFO, Processing ticker ADI
# 2024-11-20 13:14:40,361, data_manager.py, 109, INFO, Getting stock price data for ADI from 2000-01-01 to 2024-11-20
# 2024-11-20 13:14:40,361, data_manager.py, 109, INFO, Getting stock price data for ADI from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:14:42,119, data_manager.py, 83, INFO, Saving data for ADI by year
# 2024-11-20 13:14:42,119, data_manager.py, 83, INFO, Saving data for ADI by year
# 2024-11-20 13:14:43,092, data_manager.py, 73, INFO, Processing ticker ANSS
# 2024-11-20 13:14:43,092, data_manager.py, 73, INFO, Processing ticker ANSS
# 2024-11-20 13:14:43,094, data_manager.py, 109, INFO, Getting stock price data for ANSS from 2000-01-01 to 2024-11-20
# 2024-11-20 13:14:43,094, data_manager.py, 109, INFO, Getting stock price data for ANSS from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:14:47,575, data_manager.py, 83, INFO, Saving data for ANSS by year
# 2024-11-20 13:14:47,575, data_manager.py, 83, INFO, Saving data for ANSS by year
# 2024-11-20 13:14:48,534, data_manager.py, 73, INFO, Processing ticker AON
# 2024-11-20 13:14:48,534, data_manager.py, 73, INFO, Processing ticker AON
# 2024-11-20 13:14:48,535, data_manager.py, 109, INFO, Getting stock price data for AON from 2000-01-01 to 2024-11-20
# 2024-11-20 13:14:48,535, data_manager.py, 109, INFO, Getting stock price data for AON from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:14:49,618, data_manager.py, 83, INFO, Saving data for AON by year
# 2024-11-20 13:14:49,618, data_manager.py, 83, INFO, Saving data for AON by year
# 2024-11-20 13:14:50,597, data_manager.py, 73, INFO, Processing ticker APA
# 2024-11-20 13:14:50,597, data_manager.py, 73, INFO, Processing ticker APA
# 2024-11-20 13:14:50,601, data_manager.py, 109, INFO, Getting stock price data for APA from 2000-01-01 to 2024-11-20
# 2024-11-20 13:14:50,601, data_manager.py, 109, INFO, Getting stock price data for APA from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:14:56,028, data_manager.py, 83, INFO, Saving data for APA by year
# 2024-11-20 13:14:56,028, data_manager.py, 83, INFO, Saving data for APA by year
# 2024-11-20 13:14:57,132, data_manager.py, 73, INFO, Processing ticker AAPL
# 2024-11-20 13:14:57,132, data_manager.py, 73, INFO, Processing ticker AAPL
# 2024-11-20 13:14:57,134, data_manager.py, 109, INFO, Getting stock price data for AAPL from 2000-01-01 to 2024-11-20
# 2024-11-20 13:14:57,134, data_manager.py, 109, INFO, Getting stock price data for AAPL from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:14:58,478, data_manager.py, 83, INFO, Saving data for AAPL by year
# 2024-11-20 13:14:58,478, data_manager.py, 83, INFO, Saving data for AAPL by year
# 2024-11-20 13:14:59,643, data_manager.py, 73, INFO, Processing ticker AMAT
# 2024-11-20 13:14:59,643, data_manager.py, 73, INFO, Processing ticker AMAT
# 2024-11-20 13:14:59,644, data_manager.py, 109, INFO, Getting stock price data for AMAT from 2000-01-01 to 2024-11-20
# 2024-11-20 13:14:59,644, data_manager.py, 109, INFO, Getting stock price data for AMAT from 2000-01-01 to 2024-11-20
# Failed to get ticker 'AMAT' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AMAT']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# 2024-11-20 13:15:00,417, data_manager.py, 83, INFO, Saving data for AMAT by year
# 2024-11-20 13:15:00,417, data_manager.py, 83, INFO, Saving data for AMAT by year
# 2024-11-20 13:15:00,419, data_manager.py, 101, WARNING, No data found for AMAT
# 2024-11-20 13:15:00,419, data_manager.py, 101, WARNING, No data found for AMAT
# 2024-11-20 13:15:00,422, data_manager.py, 73, INFO, Processing ticker APTV
# 2024-11-20 13:15:00,422, data_manager.py, 73, INFO, Processing ticker APTV
# 2024-11-20 13:15:00,426, data_manager.py, 109, INFO, Getting stock price data for APTV from 2000-01-01 to 2024-11-20
# 2024-11-20 13:15:00,426, data_manager.py, 109, INFO, Getting stock price data for APTV from 2000-01-01 to 2024-11-20
# Failed to get ticker 'APTV' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['APTV']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# 2024-11-20 13:15:01,332, data_manager.py, 83, INFO, Saving data for APTV by year
# 2024-11-20 13:15:01,332, data_manager.py, 83, INFO, Saving data for APTV by year
# 2024-11-20 13:15:01,336, data_manager.py, 101, WARNING, No data found for APTV
# 2024-11-20 13:15:01,336, data_manager.py, 101, WARNING, No data found for APTV
# 2024-11-20 13:15:01,341, data_manager.py, 73, INFO, Processing ticker ACGL
# 2024-11-20 13:15:01,341, data_manager.py, 73, INFO, Processing ticker ACGL
# 2024-11-20 13:15:01,344, data_manager.py, 109, INFO, Getting stock price data for ACGL from 2000-01-01 to 2024-11-20
# 2024-11-20 13:15:01,344, data_manager.py, 109, INFO, Getting stock price data for ACGL from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:15:10,269, data_manager.py, 83, INFO, Saving data for ACGL by year
# 2024-11-20 13:15:10,269, data_manager.py, 83, INFO, Saving data for ACGL by year
# 2024-11-20 13:15:11,259, data_manager.py, 73, INFO, Processing ticker ADM
# 2024-11-20 13:15:11,259, data_manager.py, 73, INFO, Processing ticker ADM
# 2024-11-20 13:15:11,260, data_manager.py, 109, INFO, Getting stock price data for ADM from 2000-01-01 to 2024-11-20
# 2024-11-20 13:15:11,260, data_manager.py, 109, INFO, Getting stock price data for ADM from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:15:13,260, data_manager.py, 83, INFO, Saving data for ADM by year
# 2024-11-20 13:15:13,260, data_manager.py, 83, INFO, Saving data for ADM by year
# 2024-11-20 13:15:14,478, data_manager.py, 73, INFO, Processing ticker ANET
# 2024-11-20 13:15:14,478, data_manager.py, 73, INFO, Processing ticker ANET
# 2024-11-20 13:15:14,480, data_manager.py, 109, INFO, Getting stock price data for ANET from 2000-01-01 to 2024-11-20
# 2024-11-20 13:15:14,480, data_manager.py, 109, INFO, Getting stock price data for ANET from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:15:16,036, data_manager.py, 83, INFO, Saving data for ANET by year
# 2024-11-20 13:15:16,036, data_manager.py, 83, INFO, Saving data for ANET by year
# 2024-11-20 13:15:16,458, data_manager.py, 73, INFO, Processing ticker AJG
# 2024-11-20 13:15:16,458, data_manager.py, 73, INFO, Processing ticker AJG
# 2024-11-20 13:15:16,460, data_manager.py, 109, INFO, Getting stock price data for AJG from 2000-01-01 to 2024-11-20
# 2024-11-20 13:15:16,460, data_manager.py, 109, INFO, Getting stock price data for AJG from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:15:20,396, data_manager.py, 83, INFO, Saving data for AJG by year
# 2024-11-20 13:15:20,396, data_manager.py, 83, INFO, Saving data for AJG by year
# 2024-11-20 13:15:21,359, data_manager.py, 73, INFO, Processing ticker AIZ
# 2024-11-20 13:15:21,359, data_manager.py, 73, INFO, Processing ticker AIZ
# 2024-11-20 13:15:21,360, data_manager.py, 109, INFO, Getting stock price data for AIZ from 2000-01-01 to 2024-11-20
# 2024-11-20 13:15:21,360, data_manager.py, 109, INFO, Getting stock price data for AIZ from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:15:31,259, data_manager.py, 83, INFO, Saving data for AIZ by year
# 2024-11-20 13:15:31,259, data_manager.py, 83, INFO, Saving data for AIZ by year
# 2024-11-20 13:15:32,063, data_manager.py, 73, INFO, Processing ticker T
# 2024-11-20 13:15:32,063, data_manager.py, 73, INFO, Processing ticker T
# 2024-11-20 13:15:32,064, data_manager.py, 109, INFO, Getting stock price data for T from 2000-01-01 to 2024-11-20
# 2024-11-20 13:15:32,064, data_manager.py, 109, INFO, Getting stock price data for T from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:15:34,784, data_manager.py, 83, INFO, Saving data for T by year
# 2024-11-20 13:15:34,784, data_manager.py, 83, INFO, Saving data for T by year
# 2024-11-20 13:15:35,741, data_manager.py, 73, INFO, Processing ticker ATO
# 2024-11-20 13:15:35,741, data_manager.py, 73, INFO, Processing ticker ATO
# 2024-11-20 13:15:35,742, data_manager.py, 109, INFO, Getting stock price data for ATO from 2000-01-01 to 2024-11-20
# 2024-11-20 13:15:35,742, data_manager.py, 109, INFO, Getting stock price data for ATO from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ATO']: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)"))
# 2024-11-20 13:15:47,136, data_manager.py, 83, INFO, Saving data for ATO by year
# 2024-11-20 13:15:47,136, data_manager.py, 83, INFO, Saving data for ATO by year
# 2024-11-20 13:15:47,143, data_manager.py, 101, WARNING, No data found for ATO
# 2024-11-20 13:15:47,143, data_manager.py, 101, WARNING, No data found for ATO
# 2024-11-20 13:15:47,149, data_manager.py, 73, INFO, Processing ticker ADSK
# 2024-11-20 13:15:47,149, data_manager.py, 73, INFO, Processing ticker ADSK
# 2024-11-20 13:15:47,152, data_manager.py, 109, INFO, Getting stock price data for ADSK from 2000-01-01 to 2024-11-20
# 2024-11-20 13:15:47,152, data_manager.py, 109, INFO, Getting stock price data for ADSK from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:15:51,366, data_manager.py, 83, INFO, Saving data for ADSK by year
# 2024-11-20 13:15:51,366, data_manager.py, 83, INFO, Saving data for ADSK by year
# 2024-11-20 13:15:52,315, data_manager.py, 73, INFO, Processing ticker ADP
# 2024-11-20 13:15:52,315, data_manager.py, 73, INFO, Processing ticker ADP
# 2024-11-20 13:15:52,318, data_manager.py, 109, INFO, Getting stock price data for ADP from 2000-01-01 to 2024-11-20
# 2024-11-20 13:15:52,318, data_manager.py, 109, INFO, Getting stock price data for ADP from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:15:54,406, data_manager.py, 83, INFO, Saving data for ADP by year
# 2024-11-20 13:15:54,406, data_manager.py, 83, INFO, Saving data for ADP by year
# 2024-11-20 13:15:55,367, data_manager.py, 73, INFO, Processing ticker AZO
# 2024-11-20 13:15:55,367, data_manager.py, 73, INFO, Processing ticker AZO
# 2024-11-20 13:15:55,367, data_manager.py, 109, INFO, Getting stock price data for AZO from 2000-01-01 to 2024-11-20
# 2024-11-20 13:15:55,367, data_manager.py, 109, INFO, Getting stock price data for AZO from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:15:56,636, data_manager.py, 83, INFO, Saving data for AZO by year
# 2024-11-20 13:15:56,636, data_manager.py, 83, INFO, Saving data for AZO by year
# 2024-11-20 13:15:57,592, data_manager.py, 73, INFO, Processing ticker AVB
# 2024-11-20 13:15:57,592, data_manager.py, 73, INFO, Processing ticker AVB
# 2024-11-20 13:15:57,592, data_manager.py, 109, INFO, Getting stock price data for AVB from 2000-01-01 to 2024-11-20
# 2024-11-20 13:15:57,592, data_manager.py, 109, INFO, Getting stock price data for AVB from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:15:59,663, data_manager.py, 83, INFO, Saving data for AVB by year
# 2024-11-20 13:15:59,663, data_manager.py, 83, INFO, Saving data for AVB by year
# 2024-11-20 13:16:00,659, data_manager.py, 73, INFO, Processing ticker AVY
# 2024-11-20 13:16:00,659, data_manager.py, 73, INFO, Processing ticker AVY
# 2024-11-20 13:16:00,660, data_manager.py, 109, INFO, Getting stock price data for AVY from 2000-01-01 to 2024-11-20
# 2024-11-20 13:16:00,660, data_manager.py, 109, INFO, Getting stock price data for AVY from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:16:03,561, data_manager.py, 83, INFO, Saving data for AVY by year
# 2024-11-20 13:16:03,561, data_manager.py, 83, INFO, Saving data for AVY by year
# 2024-11-20 13:16:04,727, data_manager.py, 73, INFO, Processing ticker AXON
# 2024-11-20 13:16:04,727, data_manager.py, 73, INFO, Processing ticker AXON
# 2024-11-20 13:16:04,729, data_manager.py, 109, INFO, Getting stock price data for AXON from 2000-01-01 to 2024-11-20
# 2024-11-20 13:16:04,729, data_manager.py, 109, INFO, Getting stock price data for AXON from 2000-01-01 to 2024-11-20
# Failed to get ticker 'AXON' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AXON']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# 2024-11-20 13:16:11,490, data_manager.py, 83, INFO, Saving data for AXON by year
# 2024-11-20 13:16:11,490, data_manager.py, 83, INFO, Saving data for AXON by year
# 2024-11-20 13:16:11,491, data_manager.py, 101, WARNING, No data found for AXON
# 2024-11-20 13:16:11,491, data_manager.py, 101, WARNING, No data found for AXON
# 2024-11-20 13:16:11,492, data_manager.py, 73, INFO, Processing ticker BKR
# 2024-11-20 13:16:11,492, data_manager.py, 73, INFO, Processing ticker BKR
# 2024-11-20 13:16:11,493, data_manager.py, 109, INFO, Getting stock price data for BKR from 2000-01-01 to 2024-11-20
# 2024-11-20 13:16:11,493, data_manager.py, 109, INFO, Getting stock price data for BKR from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BKR']: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)"))
# 2024-11-20 13:16:22,784, data_manager.py, 83, INFO, Saving data for BKR by year
# 2024-11-20 13:16:22,784, data_manager.py, 83, INFO, Saving data for BKR by year
# 2024-11-20 13:16:22,786, data_manager.py, 101, WARNING, No data found for BKR
# 2024-11-20 13:16:22,786, data_manager.py, 101, WARNING, No data found for BKR
# 2024-11-20 13:16:22,788, data_manager.py, 73, INFO, Processing ticker BALL
# 2024-11-20 13:16:22,788, data_manager.py, 73, INFO, Processing ticker BALL
# 2024-11-20 13:16:22,789, data_manager.py, 109, INFO, Getting stock price data for BALL from 2000-01-01 to 2024-11-20
# 2024-11-20 13:16:22,789, data_manager.py, 109, INFO, Getting stock price data for BALL from 2000-01-01 to 2024-11-20
# Failed to get ticker 'BALL' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BALL']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# 2024-11-20 13:16:24,655, data_manager.py, 83, INFO, Saving data for BALL by year
# 2024-11-20 13:16:24,655, data_manager.py, 83, INFO, Saving data for BALL by year
# 2024-11-20 13:16:24,656, data_manager.py, 101, WARNING, No data found for BALL
# 2024-11-20 13:16:24,656, data_manager.py, 101, WARNING, No data found for BALL
# 2024-11-20 13:16:24,659, data_manager.py, 73, INFO, Processing ticker BAC
# 2024-11-20 13:16:24,659, data_manager.py, 73, INFO, Processing ticker BAC
# 2024-11-20 13:16:24,660, data_manager.py, 109, INFO, Getting stock price data for BAC from 2000-01-01 to 2024-11-20
# 2024-11-20 13:16:24,660, data_manager.py, 109, INFO, Getting stock price data for BAC from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:16:26,749, data_manager.py, 83, INFO, Saving data for BAC by year
# 2024-11-20 13:16:26,749, data_manager.py, 83, INFO, Saving data for BAC by year
# 2024-11-20 13:16:27,684, data_manager.py, 73, INFO, Processing ticker BK
# 2024-11-20 13:16:27,684, data_manager.py, 73, INFO, Processing ticker BK
# 2024-11-20 13:16:27,684, data_manager.py, 109, INFO, Getting stock price data for BK from 2000-01-01 to 2024-11-20
# 2024-11-20 13:16:27,684, data_manager.py, 109, INFO, Getting stock price data for BK from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BK']: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)"))
# 2024-11-20 13:16:38,103, data_manager.py, 83, INFO, Saving data for BK by year
# 2024-11-20 13:16:38,103, data_manager.py, 83, INFO, Saving data for BK by year
# 2024-11-20 13:16:38,107, data_manager.py, 101, WARNING, No data found for BK
# 2024-11-20 13:16:38,107, data_manager.py, 101, WARNING, No data found for BK
# 2024-11-20 13:16:38,109, data_manager.py, 73, INFO, Processing ticker BBWI
# 2024-11-20 13:16:38,109, data_manager.py, 73, INFO, Processing ticker BBWI
# 2024-11-20 13:16:38,110, data_manager.py, 109, INFO, Getting stock price data for BBWI from 2000-01-01 to 2024-11-20
# 2024-11-20 13:16:38,110, data_manager.py, 109, INFO, Getting stock price data for BBWI from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:16:45,723, data_manager.py, 83, INFO, Saving data for BBWI by year
# 2024-11-20 13:16:45,723, data_manager.py, 83, INFO, Saving data for BBWI by year
# 2024-11-20 13:16:46,654, data_manager.py, 73, INFO, Processing ticker BAX
# 2024-11-20 13:16:46,654, data_manager.py, 73, INFO, Processing ticker BAX
# 2024-11-20 13:16:46,655, data_manager.py, 109, INFO, Getting stock price data for BAX from 2000-01-01 to 2024-11-20
# 2024-11-20 13:16:46,655, data_manager.py, 109, INFO, Getting stock price data for BAX from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BAX']: ReadTimeout(ReadTimeoutError("HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)"))
# 2024-11-20 13:16:56,812, data_manager.py, 83, INFO, Saving data for BAX by year
# 2024-11-20 13:16:56,812, data_manager.py, 83, INFO, Saving data for BAX by year
# 2024-11-20 13:16:56,812, data_manager.py, 101, WARNING, No data found for BAX
# 2024-11-20 13:16:56,812, data_manager.py, 101, WARNING, No data found for BAX
# 2024-11-20 13:16:56,815, data_manager.py, 73, INFO, Processing ticker BDX
# 2024-11-20 13:16:56,815, data_manager.py, 73, INFO, Processing ticker BDX
# 2024-11-20 13:16:56,816, data_manager.py, 109, INFO, Getting stock price data for BDX from 2000-01-01 to 2024-11-20
# 2024-11-20 13:16:56,816, data_manager.py, 109, INFO, Getting stock price data for BDX from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:17:06,489, data_manager.py, 83, INFO, Saving data for BDX by year
# 2024-11-20 13:17:06,489, data_manager.py, 83, INFO, Saving data for BDX by year
# 2024-11-20 13:17:07,435, data_manager.py, 73, INFO, Processing ticker BRK.B
# 2024-11-20 13:17:07,435, data_manager.py, 73, INFO, Processing ticker BRK.B
# 2024-11-20 13:17:07,437, data_manager.py, 109, INFO, Getting stock price data for BRK.B from 2000-01-01 to 2024-11-20
# 2024-11-20 13:17:07,437, data_manager.py, 109, INFO, Getting stock price data for BRK.B from 2000-01-01 to 2024-11-20
# Failed to get ticker 'BRK.B' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BRK.B']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# 2024-11-20 13:17:10,958, data_manager.py, 83, INFO, Saving data for BRK.B by year
# 2024-11-20 13:17:10,958, data_manager.py, 83, INFO, Saving data for BRK.B by year
# 2024-11-20 13:17:10,961, data_manager.py, 101, WARNING, No data found for BRK.B
# 2024-11-20 13:17:10,961, data_manager.py, 101, WARNING, No data found for BRK.B
# 2024-11-20 13:17:10,962, data_manager.py, 73, INFO, Processing ticker BBY
# 2024-11-20 13:17:10,962, data_manager.py, 73, INFO, Processing ticker BBY
# 2024-11-20 13:17:10,963, data_manager.py, 109, INFO, Getting stock price data for BBY from 2000-01-01 to 2024-11-20
# 2024-11-20 13:17:10,963, data_manager.py, 109, INFO, Getting stock price data for BBY from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['BBY']: JSONDecodeError('Expecting value: line 1 column 1 (char 0)')
# 2024-11-20 13:17:13,381, data_manager.py, 83, INFO, Saving data for BBY by year
# 2024-11-20 13:17:13,381, data_manager.py, 83, INFO, Saving data for BBY by year
# 2024-11-20 13:17:13,387, data_manager.py, 101, WARNING, No data found for BBY
# 2024-11-20 13:17:13,387, data_manager.py, 101, WARNING, No data found for BBY
# 2024-11-20 13:17:13,391, data_manager.py, 73, INFO, Processing ticker BIO
# 2024-11-20 13:17:13,391, data_manager.py, 73, INFO, Processing ticker BIO
# 2024-11-20 13:17:13,394, data_manager.py, 109, INFO, Getting stock price data for BIO from 2000-01-01 to 2024-11-20
# 2024-11-20 13:17:13,394, data_manager.py, 109, INFO, Getting stock price data for BIO from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:17:16,027, data_manager.py, 83, INFO, Saving data for BIO by year
# 2024-11-20 13:17:16,027, data_manager.py, 83, INFO, Saving data for BIO by year
# 2024-11-20 13:17:16,956, data_manager.py, 73, INFO, Processing ticker TECH
# 2024-11-20 13:17:16,956, data_manager.py, 73, INFO, Processing ticker TECH
# 2024-11-20 13:17:16,957, data_manager.py, 109, INFO, Getting stock price data for TECH from 2000-01-01 to 2024-11-20
# 2024-11-20 13:17:16,957, data_manager.py, 109, INFO, Getting stock price data for TECH from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:17:18,312, data_manager.py, 83, INFO, Saving data for TECH by year
# 2024-11-20 13:17:18,312, data_manager.py, 83, INFO, Saving data for TECH by year
# 2024-11-20 13:17:19,290, data_manager.py, 73, INFO, Processing ticker BIIB
# 2024-11-20 13:17:19,290, data_manager.py, 73, INFO, Processing ticker BIIB
# ...
# Failed to get ticker 'WBD' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['WBD']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# 2024-11-20 13:51:28,312, data_manager.py, 83, INFO, Saving data for WBD by year
# 2024-11-20 13:51:28,312, data_manager.py, 83, INFO, Saving data for WBD by year
# 2024-11-20 13:51:28,314, data_manager.py, 101, WARNING, No data found for WBD
# 2024-11-20 13:51:28,314, data_manager.py, 101, WARNING, No data found for WBD
# 2024-11-20 13:51:28,316, data_manager.py, 73, INFO, Processing ticker WM
# 2024-11-20 13:51:28,316, data_manager.py, 73, INFO, Processing ticker WM
# 2024-11-20 13:51:28,317, data_manager.py, 109, INFO, Getting stock price data for WM from 2000-01-01 to 2024-11-20
# 2024-11-20 13:51:28,317, data_manager.py, 109, INFO, Getting stock price data for WM from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:51:31,575, data_manager.py, 83, INFO, Saving data for WM by year
# 2024-11-20 13:51:31,575, data_manager.py, 83, INFO, Saving data for WM by year
# 2024-11-20 13:51:32,497, data_manager.py, 73, INFO, Processing ticker WAT
# 2024-11-20 13:51:32,497, data_manager.py, 73, INFO, Processing ticker WAT
# 2024-11-20 13:51:32,498, data_manager.py, 109, INFO, Getting stock price data for WAT from 2000-01-01 to 2024-11-20
# 2024-11-20 13:51:32,498, data_manager.py, 109, INFO, Getting stock price data for WAT from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:51:33,624, data_manager.py, 83, INFO, Saving data for WAT by year
# 2024-11-20 13:51:33,624, data_manager.py, 83, INFO, Saving data for WAT by year
# 2024-11-20 13:51:34,771, data_manager.py, 73, INFO, Processing ticker WEC
# 2024-11-20 13:51:34,771, data_manager.py, 73, INFO, Processing ticker WEC
# 2024-11-20 13:51:34,773, data_manager.py, 109, INFO, Getting stock price data for WEC from 2000-01-01 to 2024-11-20
# 2024-11-20 13:51:34,773, data_manager.py, 109, INFO, Getting stock price data for WEC from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:51:36,947, data_manager.py, 83, INFO, Saving data for WEC by year
# 2024-11-20 13:51:36,947, data_manager.py, 83, INFO, Saving data for WEC by year
# 2024-11-20 13:51:37,880, data_manager.py, 73, INFO, Processing ticker WFC
# 2024-11-20 13:51:37,880, data_manager.py, 73, INFO, Processing ticker WFC
# 2024-11-20 13:51:37,881, data_manager.py, 109, INFO, Getting stock price data for WFC from 2000-01-01 to 2024-11-20
# 2024-11-20 13:51:37,881, data_manager.py, 109, INFO, Getting stock price data for WFC from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:51:41,625, data_manager.py, 83, INFO, Saving data for WFC by year
# 2024-11-20 13:51:41,625, data_manager.py, 83, INFO, Saving data for WFC by year
# 2024-11-20 13:51:42,548, data_manager.py, 73, INFO, Processing ticker WELL
# 2024-11-20 13:51:42,548, data_manager.py, 73, INFO, Processing ticker WELL
# 2024-11-20 13:51:42,549, data_manager.py, 109, INFO, Getting stock price data for WELL from 2000-01-01 to 2024-11-20
# 2024-11-20 13:51:42,549, data_manager.py, 109, INFO, Getting stock price data for WELL from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:51:44,961, data_manager.py, 83, INFO, Saving data for WELL by year
# 2024-11-20 13:51:44,961, data_manager.py, 83, INFO, Saving data for WELL by year
# 2024-11-20 13:51:45,908, data_manager.py, 73, INFO, Processing ticker WST
# 2024-11-20 13:51:45,908, data_manager.py, 73, INFO, Processing ticker WST
# 2024-11-20 13:51:45,910, data_manager.py, 109, INFO, Getting stock price data for WST from 2000-01-01 to 2024-11-20
# 2024-11-20 13:51:45,910, data_manager.py, 109, INFO, Getting stock price data for WST from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:51:49,459, data_manager.py, 83, INFO, Saving data for WST by year
# 2024-11-20 13:51:49,459, data_manager.py, 83, INFO, Saving data for WST by year
# 2024-11-20 13:51:50,585, data_manager.py, 73, INFO, Processing ticker WDC
# 2024-11-20 13:51:50,585, data_manager.py, 73, INFO, Processing ticker WDC
# 2024-11-20 13:51:50,586, data_manager.py, 109, INFO, Getting stock price data for WDC from 2000-01-01 to 2024-11-20
# 2024-11-20 13:51:50,586, data_manager.py, 109, INFO, Getting stock price data for WDC from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:51:54,218, data_manager.py, 83, INFO, Saving data for WDC by year
# 2024-11-20 13:51:54,218, data_manager.py, 83, INFO, Saving data for WDC by year
# 2024-11-20 13:51:55,137, data_manager.py, 73, INFO, Processing ticker WRK
# 2024-11-20 13:51:55,137, data_manager.py, 73, INFO, Processing ticker WRK
# 2024-11-20 13:51:55,138, data_manager.py, 109, INFO, Getting stock price data for WRK from 2000-01-01 to 2024-11-20
# 2024-11-20 13:51:55,138, data_manager.py, 109, INFO, Getting stock price data for WRK from 2000-01-01 to 2024-11-20
# Failed to get ticker 'WRK' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['WRK']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# 2024-11-20 13:51:57,132, data_manager.py, 83, INFO, Saving data for WRK by year
# 2024-11-20 13:51:57,132, data_manager.py, 83, INFO, Saving data for WRK by year
# 2024-11-20 13:51:57,133, data_manager.py, 101, WARNING, No data found for WRK
# 2024-11-20 13:51:57,133, data_manager.py, 101, WARNING, No data found for WRK
# 2024-11-20 13:51:57,134, data_manager.py, 73, INFO, Processing ticker WY
# 2024-11-20 13:51:57,134, data_manager.py, 73, INFO, Processing ticker WY
# 2024-11-20 13:51:57,135, data_manager.py, 109, INFO, Getting stock price data for WY from 2000-01-01 to 2024-11-20
# 2024-11-20 13:51:57,135, data_manager.py, 109, INFO, Getting stock price data for WY from 2000-01-01 to 2024-11-20
# Failed to get ticker 'WY' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['WY']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# 2024-11-20 13:52:07,165, data_manager.py, 83, INFO, Saving data for WY by year
# 2024-11-20 13:52:07,165, data_manager.py, 83, INFO, Saving data for WY by year
# 2024-11-20 13:52:07,168, data_manager.py, 101, WARNING, No data found for WY
# 2024-11-20 13:52:07,168, data_manager.py, 101, WARNING, No data found for WY
# 2024-11-20 13:52:07,170, data_manager.py, 73, INFO, Processing ticker WHR
# 2024-11-20 13:52:07,170, data_manager.py, 73, INFO, Processing ticker WHR
# 2024-11-20 13:52:07,173, data_manager.py, 109, INFO, Getting stock price data for WHR from 2000-01-01 to 2024-11-20
# 2024-11-20 13:52:07,173, data_manager.py, 109, INFO, Getting stock price data for WHR from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['WHR']: JSONDecodeError('Expecting value: line 1 column 1 (char 0)')
# 2024-11-20 13:52:09,441, data_manager.py, 83, INFO, Saving data for WHR by year
# 2024-11-20 13:52:09,441, data_manager.py, 83, INFO, Saving data for WHR by year
# 2024-11-20 13:52:09,445, data_manager.py, 101, WARNING, No data found for WHR
# 2024-11-20 13:52:09,445, data_manager.py, 101, WARNING, No data found for WHR
# 2024-11-20 13:52:09,447, data_manager.py, 73, INFO, Processing ticker WMB
# 2024-11-20 13:52:09,447, data_manager.py, 73, INFO, Processing ticker WMB
# 2024-11-20 13:52:09,449, data_manager.py, 109, INFO, Getting stock price data for WMB from 2000-01-01 to 2024-11-20
# 2024-11-20 13:52:09,449, data_manager.py, 109, INFO, Getting stock price data for WMB from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['WMB']: JSONDecodeError('Expecting value: line 1 column 1 (char 0)')
# 2024-11-20 13:52:16,800, data_manager.py, 83, INFO, Saving data for WMB by year
# 2024-11-20 13:52:16,800, data_manager.py, 83, INFO, Saving data for WMB by year
# 2024-11-20 13:52:16,802, data_manager.py, 101, WARNING, No data found for WMB
# 2024-11-20 13:52:16,802, data_manager.py, 101, WARNING, No data found for WMB
# 2024-11-20 13:52:16,802, data_manager.py, 73, INFO, Processing ticker WTW
# 2024-11-20 13:52:16,802, data_manager.py, 73, INFO, Processing ticker WTW
# 2024-11-20 13:52:16,804, data_manager.py, 109, INFO, Getting stock price data for WTW from 2000-01-01 to 2024-11-20
# 2024-11-20 13:52:16,804, data_manager.py, 109, INFO, Getting stock price data for WTW from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:52:17,992, data_manager.py, 83, INFO, Saving data for WTW by year
# 2024-11-20 13:52:17,992, data_manager.py, 83, INFO, Saving data for WTW by year
# 2024-11-20 13:52:19,062, data_manager.py, 73, INFO, Processing ticker GWW
# 2024-11-20 13:52:19,062, data_manager.py, 73, INFO, Processing ticker GWW
# 2024-11-20 13:52:19,064, data_manager.py, 109, INFO, Getting stock price data for GWW from 2000-01-01 to 2024-11-20
# 2024-11-20 13:52:19,064, data_manager.py, 109, INFO, Getting stock price data for GWW from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['GWW']: JSONDecodeError('Expecting value: line 1 column 1 (char 0)')
# 2024-11-20 13:52:19,895, data_manager.py, 83, INFO, Saving data for GWW by year
# 2024-11-20 13:52:19,895, data_manager.py, 83, INFO, Saving data for GWW by year
# 2024-11-20 13:52:19,897, data_manager.py, 101, WARNING, No data found for GWW
# 2024-11-20 13:52:19,897, data_manager.py, 101, WARNING, No data found for GWW
# 2024-11-20 13:52:19,902, data_manager.py, 73, INFO, Processing ticker WYNN
# 2024-11-20 13:52:19,902, data_manager.py, 73, INFO, Processing ticker WYNN
# 2024-11-20 13:52:19,904, data_manager.py, 109, INFO, Getting stock price data for WYNN from 2000-01-01 to 2024-11-20
# 2024-11-20 13:52:19,904, data_manager.py, 109, INFO, Getting stock price data for WYNN from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:52:21,886, data_manager.py, 83, INFO, Saving data for WYNN by year
# 2024-11-20 13:52:21,886, data_manager.py, 83, INFO, Saving data for WYNN by year
# 2024-11-20 13:52:23,074, data_manager.py, 73, INFO, Processing ticker XEL
# 2024-11-20 13:52:23,074, data_manager.py, 73, INFO, Processing ticker XEL
# 2024-11-20 13:52:23,075, data_manager.py, 109, INFO, Getting stock price data for XEL from 2000-01-01 to 2024-11-20
# 2024-11-20 13:52:23,075, data_manager.py, 109, INFO, Getting stock price data for XEL from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:52:23,952, data_manager.py, 83, INFO, Saving data for XEL by year
# 2024-11-20 13:52:23,952, data_manager.py, 83, INFO, Saving data for XEL by year
# 2024-11-20 13:52:25,242, data_manager.py, 73, INFO, Processing ticker XYL
# 2024-11-20 13:52:25,242, data_manager.py, 73, INFO, Processing ticker XYL
# 2024-11-20 13:52:25,243, data_manager.py, 109, INFO, Getting stock price data for XYL from 2000-01-01 to 2024-11-20
# 2024-11-20 13:52:25,243, data_manager.py, 109, INFO, Getting stock price data for XYL from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:52:27,228, data_manager.py, 83, INFO, Saving data for XYL by year
# 2024-11-20 13:52:27,228, data_manager.py, 83, INFO, Saving data for XYL by year
# 2024-11-20 13:52:27,946, data_manager.py, 73, INFO, Processing ticker YUM
# 2024-11-20 13:52:27,946, data_manager.py, 73, INFO, Processing ticker YUM
# 2024-11-20 13:52:27,947, data_manager.py, 109, INFO, Getting stock price data for YUM from 2000-01-01 to 2024-11-20
# 2024-11-20 13:52:27,947, data_manager.py, 109, INFO, Getting stock price data for YUM from 2000-01-01 to 2024-11-20
# Failed to get ticker 'YUM' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['YUM']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# 2024-11-20 13:52:30,235, data_manager.py, 83, INFO, Saving data for YUM by year
# 2024-11-20 13:52:30,235, data_manager.py, 83, INFO, Saving data for YUM by year
# 2024-11-20 13:52:30,237, data_manager.py, 101, WARNING, No data found for YUM
# 2024-11-20 13:52:30,237, data_manager.py, 101, WARNING, No data found for YUM
# 2024-11-20 13:52:30,238, data_manager.py, 73, INFO, Processing ticker ZBRA
# 2024-11-20 13:52:30,238, data_manager.py, 73, INFO, Processing ticker ZBRA
# 2024-11-20 13:52:30,240, data_manager.py, 109, INFO, Getting stock price data for ZBRA from 2000-01-01 to 2024-11-20
# 2024-11-20 13:52:30,240, data_manager.py, 109, INFO, Getting stock price data for ZBRA from 2000-01-01 to 2024-11-20
# Failed to get ticker 'ZBRA' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ZBRA']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# 2024-11-20 13:52:31,033, data_manager.py, 83, INFO, Saving data for ZBRA by year
# 2024-11-20 13:52:31,033, data_manager.py, 83, INFO, Saving data for ZBRA by year
# 2024-11-20 13:52:31,036, data_manager.py, 101, WARNING, No data found for ZBRA
# 2024-11-20 13:52:31,036, data_manager.py, 101, WARNING, No data found for ZBRA
# 2024-11-20 13:52:31,042, data_manager.py, 73, INFO, Processing ticker ZBH
# 2024-11-20 13:52:31,042, data_manager.py, 73, INFO, Processing ticker ZBH
# 2024-11-20 13:52:31,044, data_manager.py, 109, INFO, Getting stock price data for ZBH from 2000-01-01 to 2024-11-20
# 2024-11-20 13:52:31,044, data_manager.py, 109, INFO, Getting stock price data for ZBH from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:52:32,350, data_manager.py, 83, INFO, Saving data for ZBH by year
# 2024-11-20 13:52:32,350, data_manager.py, 83, INFO, Saving data for ZBH by year
# 2024-11-20 13:52:33,727, data_manager.py, 73, INFO, Processing ticker ZION
# 2024-11-20 13:52:33,727, data_manager.py, 73, INFO, Processing ticker ZION
# 2024-11-20 13:52:33,728, data_manager.py, 109, INFO, Getting stock price data for ZION from 2000-01-01 to 2024-11-20
# 2024-11-20 13:52:33,728, data_manager.py, 109, INFO, Getting stock price data for ZION from 2000-01-01 to 2024-11-20
# [*********************100%%**********************]  1 of 1 completed
# 2024-11-20 13:52:36,335, data_manager.py, 83, INFO, Saving data for ZION by year
# 2024-11-20 13:52:36,335, data_manager.py, 83, INFO, Saving data for ZION by year
# 2024-11-20 13:52:37,680, data_manager.py, 73, INFO, Processing ticker ZTS
# 2024-11-20 13:52:37,680, data_manager.py, 73, INFO, Processing ticker ZTS
# 2024-11-20 13:52:37,681, data_manager.py, 109, INFO, Getting stock price data for ZTS from 2000-01-01 to 2024-11-20
# 2024-11-20 13:52:37,681, data_manager.py, 109, INFO, Getting stock price data for ZTS from 2000-01-01 to 2024-11-20
# Failed to get ticker 'ZTS' reason: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out. (read timeout=10)
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['ZTS']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# 2024-11-20 13:52:47,727, data_manager.py, 83, INFO, Saving data for ZTS by year
# 2024-11-20 13:52:47,727, data_manager.py, 83, INFO, Saving data for ZTS by year
# 2024-11-20 13:52:47,728, data_manager.py, 101, WARNING, No data found for ZTS
# 2024-11-20 13:52:47,728, data_manager.py, 101, WARNING, No data found for ZTS

# %% [markdown]
# Finally, add features to our data set and save to a *feature store*.

# %%
dm.featurize()
# Out:
# 2024-11-20 13:53:06,005, data_manager.py, 121, INFO, Creating features data.
# 2024-11-20 13:53:06,005, data_manager.py, 121, INFO, Creating features data.
# 2024-11-20 13:53:06,008, data_manager.py, 132, INFO, Loading price data from ../../05_src/data/prices/
# 2024-11-20 13:53:06,008, data_manager.py, 132, INFO, Loading price data from ../../05_src/data/prices/
# c:\Users\ADYL\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\core.py:5517: UserWarning: New index has same name as existing, this is a no-op.
#   warnings.warn(
# 2024-11-20 13:53:08,191, data_manager.py, 140, INFO, Creating features
# 2024-11-20 13:53:08,191, data_manager.py, 140, INFO, Creating features
# a:\UofT\production\01_materials\labs\../../05_src\data_manager.py:142: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   features = (price_dd
# 2024-11-20 13:53:08,272, data_manager.py, 158, INFO, Creating target
# 2024-11-20 13:53:08,272, data_manager.py, 158, INFO, Creating target
# a:\UofT\production\01_materials\labs\../../05_src\data_manager.py:159: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   self.features = (self.features.groupby('ticker', group_keys=False).apply(
# 2024-11-20 13:53:08,346, data_manager.py, 168, INFO, Saving features to ../../05_src/data/features/stock_features.parquet
# 2024-11-20 13:53:08,346, data_manager.py, 168, INFO, Saving features to ../../05_src/data/features/stock_features.parquet
